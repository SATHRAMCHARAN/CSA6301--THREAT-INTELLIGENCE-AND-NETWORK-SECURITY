# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6301--THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/exp37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Defense in Depth Simulation

def simulate_defense(attack, layers):
    """
    layers: list of (layer_name, catch_function)

    Returns the first security layer that blocks the attack,
    or 'BREACH' if no layer detects it.
    """
    for layer_name, catch_fn in layers:
        if catch_fn(attack):
            return layer_name

    return "BREACH"


# Security Layers
def spam_filter_catches(attack):
    return attack.get("known_phishing_domain", False)


def endpoint_av_catches(attack):
    return attack.get("known_malware_hash", False)


def segmentation_catches(attack):
    return (
        attack.get("attempts_lateral_movement", False)
        and not attack.get("segmentation_bypassed", False)
    )


def siem_monitoring_catches(attack):
    return attack.get("generates_anomalous_traffic", False)


# Ordered defense layers
layers = [
    ("Spam Filter", spam_filter_catches),
    ("Endpoint Antivirus", endpoint_av_catches),
    ("Network Segmentation", segmentation_catches),
    ("SIEM Monitoring", siem_monitoring_catches),
]

# Sample attack
attack = {
    "known_phishing_domain": False,
    "known_malware_hash": True,
    "attempts_lateral_movement": True,
    "segmentation_bypassed": False,
    "generates_anomalous_traffic": True,
}

# Simulate defense
result = simulate_defense(attack, layers)

print("Attack Blocked By:", result)
# Out:
# Attack Blocked By: Endpoint Antivirus
