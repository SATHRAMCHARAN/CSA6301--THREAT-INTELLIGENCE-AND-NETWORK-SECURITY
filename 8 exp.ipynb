# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6301--THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/8%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib

def hash_password(password):
    return hashlib.sha256(password.encode()).hexdigest()

stored_hash = hash_password("satthu123")

password = input("Enter password to verify: ")

input_hash = hash_password(password)

if input_hash == stored_hash:
    print("Password verified successfully.")
else:
    print("Incorrect password.")
# Out:
# Enter password to verify: satthu123
# Password verified successfully.
