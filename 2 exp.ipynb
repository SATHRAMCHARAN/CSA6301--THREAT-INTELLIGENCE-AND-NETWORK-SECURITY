# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6301--THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/2%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import os

def generate_hash(file_path):
    sha256 = hashlib.sha256()

    with open(file_path, "rb") as file:
        for block in iter(lambda: file.read(4096), b""):
            sha256.update(block)

    return sha256.hexdigest()


# Create sample file
file_name = "sample.txt"

with open(file_name, "w") as file:
    file.write("This is a confidential file.")

print("File created:", file_name)

# Generate original hash
original_hash = generate_hash(file_name)

print("\nOriginal SHA-256 Hash:")
print(original_hash)

# User modifies file
choice = input("\nDo you want to modify the file? (yes/no): ")

if choice.lower() == "yes":
    with open(file_name, "w") as file:
        file.write("This file has been modified.")

# Generate new hash
new_hash = generate_hash(file_name)

print("\nNew SHA-256 Hash:")
print(new_hash)

# Compare hashes
if original_hash == new_hash:
    print("\nFile Integrity Verified: No tampering detected.")
else:
    print("\nFile Tampered: Integrity compromised.")
# Out:
# File created: sample.txt
#
# Original SHA-256 Hash:
# 4b544a2aa3bb04a2bebf5fd92e60fc80cb0e6fb08a57f7b49ed90ab423b5c4f3
#
# Do you want to modify the file? (yes/no): yes
#
# New SHA-256 Hash:
# 40c7d390ded397f9655336fa9f9cfaa533b41e1f7b8efb32bc947e4a96f1802f
#
# File Tampered: Integrity compromised.
