# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6301--THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/exp24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Set random seed for reproducibility
random.seed(42)

# Generate event stream
def generate_event_stream(n=20):
    stream = []

    for _ in range(n):
        stream.append({
            "hour": random.choice([9, 10, 11, 14, 15, 16]),  # Normal business hours
            "failed_logins": random.choice([0, 0, 0, 1]),
        })

    # Inject anomalies
    stream.append({"hour": 3, "failed_logins": 0})
    stream.append({"hour": 10, "failed_logins": 9})

    return stream

# Monitor stream for anomalies
def monitor_stream(stream):
    flags = []

    for event in stream:
        reasons = []

        if event["hour"] < 6 or event["hour"] > 22:
            reasons.append("off-hours activity")

        if event["failed_logins"] >= 5:
            reasons.append("excessive failed logins")

        if reasons:
            flags.append({
                "event": event,
                "reasons": reasons
            })

    return flags

# Generate and analyze stream
event_stream = generate_event_stream()
flags = monitor_stream(event_stream)

print(f"Stream length: {len(event_stream)}")
print(f"Flags raised: {len(flags)}\n")

for flag in flags:
    print(flag)
# Out:
# Stream length: 22
# Flags raised: 2
#
# {'event': {'hour': 3, 'failed_logins': 0}, 'reasons': ['off-hours activity']}
# {'event': {'hour': 10, 'failed_logins': 9}, 'reasons': ['excessive failed logins']}
