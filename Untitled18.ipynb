# %% [markdown]
# <a href="https://colab.research.google.com/github/SATHRAMCHARAN/CSA6301--THREAT-INTELLIGENCE-AND-NETWORK-SECURITY/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

# Target host
target = "scanme.nmap.org"

# Common ports to scan
ports = [21, 22, 23, 25, 53, 80, 110, 143, 443]

print(f"Scanning Host: {target}\n")

for port in ports:
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(1)

    result = s.connect_ex((target, port))

    if result == 0:
        print(f"Port {port}: OPEN")
    else:
        print(f"Port {port}: CLOSED")

    s.close()

print("\nPort Scan Completed.")
# Out:
# Scanning Host: scanme.nmap.org
#
# Port 21: CLOSED
# Port 22: OPEN
# Port 23: CLOSED
# Port 25: CLOSED
# Port 53: CLOSED
# Port 80: OPEN
# Port 110: CLOSED
# Port 143: CLOSED
# Port 443: CLOSED
#
# Port Scan Completed.
